# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('hscdata.csv')
data
# Out:
#      JSC   SSC   HSC
# 0   5.00  5.00  5.00
# 1   5.00  5.00  5.00
# 2   4.50  4.70  4.90
# 3   4.00  4.50  4.70
# 4   3.50  3.90  4.20
# 5   5.00  5.00  4.80
# 6   5.00  4.00  4.50
# 7   4.80  4.70  4.40
# 8   2.90  3.20  3.10
# 9   2.80  3.00  3.00
# 10  3.50  3.80  3.70
# 11  4.90  4.80  4.60
# 12  5.00  4.50  4.80
# 13  3.80  3.90  4.00
# 14  3.70  3.50  3.40
# 15  3.80  3.90  4.00
# 16  4.20  4.30  4.00
# 17  4.70  3.80  4.00
# 18  4.80  4.70  4.60
# 19  5.00  4.00  4.50
# 20  4.70  4.80  4.90
# 21  4.80  4.90  4.80
# 22  4.74  5.00  4.80
# 23  4.80  4.70  4.60
# 24  4.67  4.95  4.80
# 25  4.58  4.50  4.50
# 26  4.25  4.80  4.60
# 27  4.50  4.60  4.50
# 28  4.55  4.35  4.40
# 29  4.83  4.75  4.80
# 30  3.80  3.90  3.80
# 31  4.20  4.50  4.30
# 32  2.80  2.90  2.90
# 33  3.92  4.20  4.00
# 34  3.20  3.70  3.50
# 35  4.20  4.30  4.25
# 36  4.85  4.65  4.66
# 37  4.50  3.90  4.20
# 38  5.00  5.00  5.00
# 39  5.00  4.70  4.90
# 40  4.80  4.70  4.80
# 41  5.00  5.00  4.96
# 42  4.90  4.90  4.80
# 43  4.90  4.70  4.80
# 44  5.00  4.50  4.75
# 45  4.20  4.50  4.30
# 46  4.25  4.50  4.40
# 47  4.40  4.60  4.50
# 48  4.30  4.40  4.35

# %%
plt.xlabel('JSC')
plt.ylabel('SSC')
plt.scatter(data.JSC,data.HSC,label='JSC')
plt.scatter(data.SSC,data.HSC,label='SSC')
plt.legend(loc='best',shadow=True,fontsize='small')
plt.grid()

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
x=data[['JSC','SSC']]
y=data['HSC']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(x_test,y_test)
# Out:
# 0.9241296795316893

# %%
model.predict([[5,5]])
# Out:
# array([4.95515746])

# %%
model.predict([[4.5,4.7]])
# Out:
# array([4.60351748])
